# %%
import pandas as pd
import numpy as np
import os, sys
sys.path.insert(0, os.path.abspath('../..'))
import source.data_handling.data_preparation as dp
from source.regression.configs_gw import WITHOUT_LOOKAHEAD, ALL, MINIMAL_SETTING, WITHOUT_LOOKAHEAD_AR, ALL_COVARIATES_NON_AR, ALL_COVARIATES_AR,COMPLETED
import source.Bootstrapping.models_regression as bu
import source.regression.regression_models as modl
uselog = True
data = dp.prepare_data(uselog=uselog)
# Out:
# /opt/anaconda3/envs/tsfm/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df_lag = bu.make_lagged_features(data, COMPLETED, lag=1)
feature_cols = [f"{v}_lag1" for v in COMPLETED]

df_lag["Rfree_lag1"] = data["Rfree"].shift(1)

# %%
# PCR
stats = bu.bootstrap_refit_train_test(
    df_lag,
    target_col="equity_premium",
    feature_cols=feature_cols,
    start_oos="1927-01-01",
    min_train=240,
    B=1000,
    seed=42,
    bootstrap="iid",
    model="pcr",
    pcr_k=1,
    ct_cutoff=True,
    pred_is_lep =uselog

)
print(stats)
# Out:
# {'r2': {'mean': -0.009704860680539072, 'std': 0.019810502100696355, 'ci_lower': -0.04830447091823092, 'ci_upper': 0.00596530254293363, 'ci': 0.9, 'n': 1000}, 'SR_ann': {'mean': 0.30927149908920776, 'std': 0.1583891598074768, 'ci_lower': 0.06580127287254804, 'ci_upper': 0.586278012113825, 'ci': 0.9, 'n': 1000}, 'CEV_ann': {'mean': 0.015177611341116132, 'std': 0.03827413017193574, 'ci_lower': -0.056395898454565864, 'ci_upper': 0.05748375467846237, 'ci': 0.9, 'n': 1000}, 'AnnVol': {'mean': 0.1302757779832157, 'std': 0.05845018939424402, 'ci_lower': 0.043112578276608776, 'ci_upper': 0.21871027563148035, 'ci': 0.9, 'n': 1000}, 'Delta_u_vs_HA': {'mean': -0.030838238469245428, 'std': 0.030900902838184273, 'ci_lower': -0.08946532913628458, 'ci_upper': 0.0010202535148168413, 'ci': 0.9, 'n': 1000}, 'Delta_u_vs_W50': {'mean': -0.03627248338812346, 'std': 0.03158629708688929, 'ci_lower': -0.09647551314830831, 'ci_upper': -0.0005709057866802916, 'ci': 0.9, 'n': 1000}, 'Delta_u_vs_W100': {'mean': -0.011634782952836726, 'std': 0.029563164817132892, 'ci_lower': -0.06138576019693327, 'ci_upper': 0.0322877834803836, 'ci': 0.9, 'n': 1000}}

# %%
# # TabPFN
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="iid",
#     model="tabpfn",
#     pcr_k=1,
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # Combo Model
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="iid",
#     model="combo",
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # PCR
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     model="pcr",
#     pcr_k=1,
#     bootstrap="mbb",
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # TabPFN
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="mbb",
#     model="tabpfn",
#     pcr_k=1,
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # Combo Model
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="mbb",
#     model="combo",
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # TabPFN
# df_lag = bu.make_lagged_features(data, WITHOUT_LOOKAHEAD_AR, lag=1)
# feature_cols = [f"{v}_lag1" for v in WITHOUT_LOOKAHEAD_AR]

# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="mbb",
#     model="tabpfn",
#     pcr_k=1,
#     ct_cutoff=True,
# )
# print(stats)

# %%
# # TabPFN
# df_lag = bu.make_lagged_features(data, COMPLETED, lag=3)
# #do feature cols from 1,2,3,
# feature_cols = [f"{v}_lag" for v in WITHOUT_LOOKAHEAD_AR]
# feature_cols = []
# for v in WITHOUT_LOOKAHEAD_AR:
#     for lag in range(1,4):
#         feature_cols.append(f"{v}_lag{lag}")

# # stats = bu.bootstrap_refit_train_test(
# #     df_lag,
# #     target_col="equity_premium",
# #     feature_cols=feature_cols,
# #     start_oos="1927-01-01",
# #     min_train=240,
# #     B=1000,
# #     seed=42,
# #     bootstrap="mbb",
# #     model="tabpfn",
# #     pcr_k=1,
# #     ct_cutoff=True,
# # )
# # print(stats)

# %%
# # PCR
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1927-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     model="pcr",
#     pcr_k=1,
#     bootstrap="mbb",
#     ct_cutoff=True,
# )
# print(stats)

# %%
# _, _, _, y_pred_m, _, _, _, HA_m = modl.chronos2_oos(
#     data[data.index >= "1927-01-01"], covariates=[], start_oos="1965-01-01",
#     ctx_min=256, ct_cutoff=True, quiet=False, mode = "mean", freq="M"
# )
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1965-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="mbb",  # recommended for ARIMA
#     block_size=12,
#     model="chronos_2",
#     ct_cutoff=True,
#     y_pred_given=y_pred_m,save_results = False
# )
# stats

# %%
# _, _, _, y_pred_m, _, _, _, HA_m = modl.chronos2_oos(
#     data[data.index >= "1927-01-01"], covariates=WITHOUT_LOOKAHEAD, start_oos="1965-01-01",
#     ctx_min=256, ct_cutoff=True, quiet=False, mode = "mean", freq="M",    save_results = False
# )
# stats = bu.bootstrap_refit_train_test(
#     df_lag,
#     target_col="equity_premium",
#     feature_cols=feature_cols,
#     start_oos="1965-01-01",
#     min_train=240,
#     B=1000,
#     seed=42,
#     bootstrap="mbb",  # recommended for ARIMA
#     block_size=12,
#     model="chronos_2",
#     ct_cutoff=True,
#     y_pred_given=y_pred_m,
# )
# stats

# %%
_, _, _, y_pred_m, _, _, _, HA_m = modl.chronos2_oos(
    data[data.index >= "1927-01-01"], covariates=COMPLETED, start_oos="1965-01-01",
    ctx_min=256, ct_cutoff=True, quiet=False, mode = "mean", freq="M",save_results = False
)
stats = bu.bootstrap_refit_train_test(
    df_lag,
    target_col="equity_premium",
    feature_cols=feature_cols,
    start_oos="1965-01-01",
    min_train=240,
    B=1000,
    seed=42,
    bootstrap="mbb",  # recommended for ARIMA
    block_size=12,
    model="chronos_2",
    ct_cutoff=True,
    y_pred_given=y_pred_m,
    pred_is_lep =uselog
)
stats
# Out:
# [Chronos-2] Loading amazon/chronos-2 on M freq with 22 covariates...
# /opt/anaconda3/envs/tsfm/lib/python3.11/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 1965-01-01 00:00:00
# /opt/anaconda3/envs/tsfm/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 1965-02-01 00:00:00
# 1965-03-01 00:00:00
# 1965-04-01 00:00:00
# 1965-05-01 00:00:00
# 1965-06-01 00:00:00
# 1965-07-01 00:00:00
# 1965-08-01 00:00:00
# 1965-09-01 00:00:00
# 1965-10-01 00:00:00
# 1965-11-01 00:00:00
# 1965-12-01 00:00:00
# 1966-01-01 00:00:00
# 1966-02-01 00:00:00
# 1966-03-01 00:00:00
# 1966-04-01 00:00:00
# 1966-05-01 00:00:00
# 1966-06-01 00:00:00
# 1966-07-01 00:00:00
# 1966-08-01 00:00:00
# 1966-09-01 00:00:00
# 1966-10-01 00:00:00
# 1966-11-01 00:00:00
# 1966-12-01 00:00:00
# 1967-01-01 00:00:00
# 1967-02-01 00:00:00
# 1967-03-01 00:00:00
# 1967-04-01 00:00:00
# 1967-05-01 00:00:00
# 1967-06-01 00:00:00
# 1967-07-01 00:00:00
# 1967-08-01 00:00:00
# 1967-09-01 00:00:00
# 1967-10-01 00:00:00
# 1967-11-01 00:00:00
# 1967-12-01 00:00:00
# 1968-01-01 00:00:00
# 1968-02-01 00:00:00
# 1968-03-01 00:00:00
# 1968-04-01 00:00:00
# 1968-05-01 00:00:00
# 1968-06-01 00:00:00
# 1968-07-01 00:00:00
# 1968-08-01 00:00:00
# 1968-09-01 00:00:00
# 1968-10-01 00:00:00
# 1968-11-01 00:00:00
# 1968-12-01 00:00:00
# 1969-01-01 00:00:00
# 1969-02-01 00:00:00
# 1969-03-01 00:00:00
# 1969-04-01 00:00:00
# 1969-05-01 00:00:00
# 1969-06-01 00:00:00
# 1969-07-01 00:00:00
# 1969-08-01 00:00:00
# 1969-09-01 00:00:00
# 1969-10-01 00:00:00
# 1969-11-01 00:00:00
# 1969-12-01 00:00:00
# 1970-01-01 00:00:00
# 1970-02-01 00:00:00
# 1970-03-01 00:00:00
# 1970-04-01 00:00:00
# 1970-05-01 00:00:00
# 2022-12-01 00:00:00
# 2023-01-01 00:00:00
# 2023-02-01 00:00:00
# 2023-03-01 00:00:00
# 2023-04-01 00:00:00
# 2023-05-01 00:00:00
# 2023-06-01 00:00:00
# 2023-07-01 00:00:00
# 2023-08-01 00:00:00
# 2023-09-01 00:00:00
# 2023-10-01 00:00:00
# 2023-11-01 00:00:00
# 2023-12-01 00:00:00
# 2024-01-01 00:00:00
# 2024-02-01 00:00:00
# 2024-03-01 00:00:00
# 2024-04-01 00:00:00
# 2024-05-01 00:00:00
# 2024-06-01 00:00:00
# 2024-07-01 00:00:00
# 2024-08-01 00:00:00
# 2024-09-01 00:00:00
# 2024-10-01 00:00:00
# 2024-11-01 00:00:00
# 2024-12-01 00:00:00
# percentage of negative forecasts before truncation: 22.36%
# Manually calculated R2: 0.008718939875288712
# [Chronos-2 (w/ Covariates)] Valid=720 | MSE=0.001895 | R²_OS=0.0087 (±0.0101)
# evaluate_oos calculated R2 CT: 0.008718939875288712
# Manually calculated Stats: {'mean': 0.008700903436349923, 'std': 0.010077300755262444, 'lower': -0.01107920982040549, 'upper': 0.026765177822097683}
# [Chronos-2 (w/ Covariates) (WCT)] Valid=720 | MSE=0.001941 | R²_OS=-0.0154 (±0.0195)
# evaluate_oos calculated R2 WCT: -0.015355128875868207
# Stats WCT: {'mean': -0.015944089667632128, 'std': 0.0194941724291741, 'lower': -0.056167183021713606, 'upper': 0.019928421098531608}
# CT Eval Summary: {'timing_spread': 0.007679251758352871, 'share_in_market': 0.7763888888888889}
# [Chronos-2 (w/ Covariates)] Valid=720 | MSE=0.001895 | R²_OS=0.0087 (±0.0101)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 5
#       1 _, _, _, y_pred_m, _, _, _, HA_m = modl.chronos2_oos(
#       2     data[data.index >= "1927-01-01"], covariates=COMPLETED, start_oos="1965-01-01",
#       3     ctx_min=256, ct_cutoff=True, quiet=False, mode = "mean", freq="M",save_results = False
#       4 )
# ----> 5 stats = bu.bootstrap_refit_train_test(
#       6     df_lag,
#       7     target_col="equity_premium",
#       8     feature_cols=feature_cols,
#       9     start_oos="1965-01-01",
#      10     min_train=240,
#      11     B=1000,
#      12     seed=42,
#      13     bootstrap="mbb",  # recommended for ARIMA
#      14     block_size=12,
#      15     model="chronos_2",
#      16     ct_cutoff=True,
#      17     y_pred_given=y_pred_m,
#      18     pred_is_lep =uselog
#      19 )
#      20 stats
#
# File ~/Masterarbeit/source/Bootstrapping/models_regression.py:444, in bootstrap_refit_train_test(df, target_col, feature_cols, start_oos, start_data, min_train, B, seed, bootstrap, block_size, model, combo, pcr_k, trim_q, ct_cutoff, y_pred_given, compute_trading, risky_ret_col, rf_ret_col, rf_lag_col, A, gamma, var_window, w_min, w_max, compute_delta_u, pred_is_lep, ep_realized_col)
#     442     y_pred_given_arr = np.asarray(y_pred_given, float)
#     443     if y_pred_given_arr.shape[0] != df.shape[0]:
# --> 444         raise ValueError("y_pred_given must have same length as df (after start_data filter).  #Changed")
#     445     yhat = y_pred_given_arr[test_mask]  #Changed  <-- correct alignment for OOB rows
#     447 else:
#
# ValueError: y_pred_given must have same length as df (after start_data filter).  #Changed

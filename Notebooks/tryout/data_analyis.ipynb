# %%
import pandas as pd
import numpy as np
import os, sys
sys.path.insert(0, os.path.abspath('../..'))
import source.data_preparation as dp
import source.regression_models as modl
data = dp.prepare_data(uselog=True)
# Out:
# /opt/anaconda3/envs/tsfm/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
data[data.index >= "1927-01-01"]
# Out:
#               price        d12         e12       ret      retx     AAA  \
# date
# 1927-01-01    13.21   0.696700    1.229000 -0.002910 -0.005579  0.0466
# 1927-02-01    13.84   0.703300    1.218000  0.045522  0.040566  0.0467
# 1927-03-01    13.93   0.710000    1.208000  0.007324  0.002610  0.0462
# 1927-04-01    14.17   0.716700    1.197000  0.013021  0.010907  0.0458
# 1927-05-01    14.91   0.723300    1.186000  0.062353  0.057096  0.0457
# ...             ...        ...         ...       ...       ...     ...
# 2024-08-01  5648.40  72.925466  198.823333  0.024283  0.022898  0.0487
# 2024-09-01  5762.48  73.400300  200.270000  0.022821  0.021707  0.0468
# 2024-10-01  5705.45  73.877618  203.570000 -0.008690 -0.009523  0.0495
# 2024-11-01  6032.38  74.354936  206.870000  0.060420  0.059016  0.0514
# 2024-12-01  5881.63  74.832255  210.170000 -0.023445 -0.024621  0.0520
#
#                BAA     lty       ltr     corpr  ...      rdsp  rsvix  gpce  \
# ...

# %%
readme = pd.read_excel("../../Data/GoyalAndWelch.xlsx", sheet_name="ReadMe")
# Out:
# /opt/anaconda3/envs/tsfm/lib/python3.11/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
readme = readme[readme["Frequency"]=="Monthly"]

# %%
a = ["vp","impvar","vrp","lzrt","ogap","wtexas","sntm","skvw","tail","fbm","dtoy","dtoat","ygap","rdsp","rsvix","tchi","avgcor","shtint","disag","ntis","lty","ltr","tms","dfy","dfr","infl"]
b = ["vp", "impvar", "vrp", "lzrt", "ogap", "wtexas", "sntm", "ndrbl", "skvw", "tail", "fbm", "dtoy", "dtoat", "ygap", "rdsp", "rsvix", "tchi", "avgcor", "shtint", "disag", "ntis", "tbl", "d/p", "d/y", "e/p", "d/e", "svar", "lty", "ltr", "tms", "dfy", "dfr", "infl", "b/m"]

# Convert to sets for comparison
set_a = set(a)
set_b = set(b)

# 1. Items in B that are NOT in A (Added items)
added = set_b - set_a

# 2. Items in A that are NOT in B (Removed items)
removed = set_a - set_b

print(f"Items in list 'b' but missing from 'a':\n{list(added)}")
print(f"\nItems in list 'a' but missing from 'b':\n{list(removed)}")
# Out:
# Items in list 'b' but missing from 'a':
# ['ndrbl', 'tbl']
#
# Items in list 'a' but missing from 'b':
# ['equity_premium']

# %%
#difference between a and b is that b  in python
